# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
trash = pd.read_csv('../trash-haulers-big_al/trash_hauler_report.csv')

# %%
trash.head()
# Out:
#    Request Number Date Opened                              Request   \
# 0           25270    11/01/17                      Trash - Backdoor
# 1           25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2           25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3           25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4           25312    11/01/17  Trash - Curbside/Alley Missed Pickup
#
#                                          Description       Incident Address  \
# 0  house with the wheel chair ramp, they share dr...         3817 Crouch Dr
# 1                           Curb/Trash miss Tuesday.  4028 Clarksville Pike
# 2                           Curb/trash miss Tuesday.    6528 Thunderbird Dr
# 3                                             missed   2603 old matthews rd
# 4                  Missed the even side of the road.          604 croley dr
#
#    Zip Code Trash Hauler Trash Route  Council District  State Plan X  \
# ...

# %%
trash
# Out:
#        Request Number Date Opened                              Request   \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash.columns = trash.columns.str.strip()

# %%
trash['Description']=trash['Description'].str.lower()
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_12036\688452568.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trash['Description']=trash['Description'].str.lower()

# %%
trash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20121 entries, 0 to 20225
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20121 non-null  int64
#  1   Date Opened       20121 non-null  object
#  2   Request           20121 non-null  object
#  3   Description       20121 non-null  object
#  4   Incident Address  20119 non-null  object
#  5   Zip Code          20121 non-null  int32
#  6   Trash Hauler      19252 non-null  object
#  7   Trash Route       19205 non-null  object
#  8   Council District  20120 non-null  float64
#  9   State Plan X      20117 non-null  float64
#  10  State Plan Y      20117 non-null  float64
#  11  Address           20119 non-null  object
#  12  City              13301 non-null  object
#  13  State             12508 non-null  object
#  14  US                12491 non-null  object
#  15  None              1 non-null      object
# ...

# %% [raw]
# trash['Date Opened'] = pd.to_datetime(trash['Date Opened'])

# %%
trash=trash.dropna(subset='Zip Code')

# %%
trash['Zip Code']=trash['Zip Code'].astype(int)

# %%
trash
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash=trash.dropna(subset='Description')

# %%
trash
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
trash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20121 entries, 0 to 20225
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Request Number    20121 non-null  int64
#  1   Date Opened       20121 non-null  object
#  2   Request           20121 non-null  object
#  3   Description       20121 non-null  object
#  4   Incident Address  20119 non-null  object
#  5   Zip Code          20121 non-null  int32
#  6   Trash Hauler      19252 non-null  object
#  7   Trash Route       19205 non-null  object
#  8   Council District  20120 non-null  float64
#  9   State Plan X      20117 non-null  float64
#  10  State Plan Y      20117 non-null  float64
#  11  Address           20119 non-null  object
#  12  City              13301 non-null  object
#  13  State             12508 non-null  object
#  14  US                12491 non-null  object
#  15  None              1 non-null      object
# ...

# %%
# population['Name'] = population['Name'].str.title()

trash['Incident Address'] = trash['Incident Address'].str.title()
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_12036\1473073961.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trash['Incident Address'] = trash['Incident Address'].str.title()

# %%
# unemployment['Name'].str.split(',')

trash['Incident Address'].str.split(',')
# Out:
# 0                                         [3817 Crouch Dr]
# 1                                  [4028 Clarksville Pike]
# 2                                    [6528 Thunderbird Dr]
# 3                                   [2603 Old Matthews Rd]
# 4                                          [604 Croley Dr]
#                                ...
# 20221                             [2731 Murfreesboro Pike]
# 20222    [1621 Long Ave,  Nashville,  Tn 37206,  United...
# 20223    [2943 Windemere Cir,  Nashville,  Tn 37214,  U...
# 20224    [3325 Murfreesboro Pike,  Nashville,  Tn 37013...
# 20225    [604 Somerset Ct,  Nashville,  Tn 37217,  Unit...
# Name: Incident Address, Length: 20121, dtype: object

# %%
# unemployment['Name'].str.split(',', expand = True)

trash[["Address", "City", "State", "US", "None"]] = trash['Incident Address'].str.split(',', expand = True)

# %%
trash
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  \
# ...

# %%
new_trash = trash.drop(columns=['Incident Address', 'City', 'State', 'US', 'None'])

# %%
new_trash
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  Zip Code  \
# ...

# %%
# country_count = gdp['Country or Area'].value_counts(). country_count.head (5)

request_count = new_trash['Request'].value_counts()
request_count
# Out:
# Request
# Trash - Curbside/Alley Missed Pickup    14944
# Trash - Backdoor                         2619
# Trash Collection Complaint               2304
# Damage to Property                        254
# Name: count, dtype: int64

# %%
new_trash
# Out:
#        Request Number Date Opened                               Request  \
# 0               25270    11/01/17                      Trash - Backdoor
# 1               25274    11/01/17  Trash - Curbside/Alley Missed Pickup
# 2               25276    11/01/17  Trash - Curbside/Alley Missed Pickup
# 3               25307    11/01/17  Trash - Curbside/Alley Missed Pickup
# 4               25312    11/01/17  Trash - Curbside/Alley Missed Pickup
# ...               ...         ...                                   ...
# 20221          267125    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20222          267126    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20223          267130    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20224          267134    11/01/19  Trash - Curbside/Alley Missed Pickup
# 20225          267137    11/01/19  Trash - Curbside/Alley Missed Pickup
#
#                                              Description  Zip Code  \
# ...
